# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('Profit_Budget_comp.xlsx')

# %%
plt.plot(df['Budget'],df['Profit'])

# %%
tick_label = ['Budget','Profit']

# %%
plt.hist(df['Budget'],df['Profit'])
# Out:
# (array([0., 0., 0., ..., 0., 0., 0.]),
#  array([-2.12710951e+09, -1.09956084e+09, -9.89962610e+08, ...,
#          4.58672302e+08,  5.02177271e+08,  5.23505847e+08]),
#  <BarContainer object of 3751 artists>)

# %%
plt.scatter(df['Budget'],df['Profit'])

# %%
data1 = df[df['Profit']>-100000000]

# %%
plt.scatter(data1['Budget'],data1['Profit'])

# %%
plt.plot(data1['Budget'],data1['Profit'])

# %%
plt.hist(data1['Budget'],data1['Profit'])
# Out:
# (array([0., 0., 0., ..., 0., 0., 0.]),
#  array([-9.93444970e+07, -9.69416200e+07, -9.65821350e+07, ...,
#          4.58672302e+08,  5.02177271e+08,  5.23505847e+08]),
#  <BarContainer object of 3720 artists>)

# %%
data1.to_csv('new_data_profit.csv')
